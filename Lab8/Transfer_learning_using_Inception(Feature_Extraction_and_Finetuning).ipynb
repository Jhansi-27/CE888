# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-973e6107-b3f3-4976-9b87-d09ba04fd078" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-973e6107-b3f3-4976-9b87-d09ba04fd078">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data (2).zip to data (2).zip

# %%
from zipfile import ZipFile
file_name = "/content/data (2).zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import os
# Get all the paths
data_dir_list = os.listdir('data')
print(data_dir_list)

import os
# Get all the paths
data_dir_list = os.listdir('data/horses')
print(data_dir_list)
data_dir_list = os.listdir('data/Humans')
print(data_dir_list)
data_dir_list = os.listdir('data/cats')
print(data_dir_list)
data_dir_list = os.listdir('data/dogs')
print(data_dir_list)
# Out:
# ['Humans', 'dogs', 'horses', 'cats']
# ...

# %%
path, dirs, files = next(os.walk("data/dogs"))
file_count = len(files)
print("dogs: ",file_count)
path, dirs, files = next(os.walk("data/Humans"))
file_count = len(files)
print("Humans: ",file_count)
path, dirs, files = next(os.walk("data/cats"))
file_count = len(files)
print("cats: ",file_count)
path, dirs, files = next(os.walk("data/horses"))
file_count = len(files)
print("horses: ",file_count)
# Out:
# dogs:  202
# Humans:  202
# cats:  202
# horses:  202

# %%
'rider-144.jpg'.split('-')[0]
# Out:
# 'rider'

# %%
# Make new base directory
original_dataset_dir = 'data'
base_dir = 'new_data'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# %%
import shutil
fnames = ['cat.{}.jpg'.format(i) for i in range(1,103)]
for fname in fnames:
    src = os.path.join('data/cats', fname)
    dst = os.path.join(train_dir, fname)
    #print(src,dst)
    shutil.copyfile(src, dst)
    
fnames = ['cat.{}.jpg'.format(i) for i in range(103, 153)]
for fname in fnames:
    src = os.path.join('data/cats', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['cat.{}.jpg'.format(i) for i in range(153, 203)]
for fname in fnames:
    src = os.path.join('data/cats', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(1,103)]
for fname in fnames:
    src = os.path.join('data/dogs', fname)
    dst = os.path.join(train_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(103, 153)]
for fname in fnames:
    src = os.path.join('data/dogs', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(153, 203)]
for fname in fnames:
    src = os.path.join('data/dogs', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['rider-{}.jpg'.format(i) for i in range(1,103)]
for fname in fnames:
    src = os.path.join('data/Humans', fname)
    dst = os.path.join(train_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['rider-{}.jpg'.format(i) for i in range(103, 153)]
for fname in fnames:
    src = os.path.join('data/Humans', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['rider-{}.jpg'.format(i) for i in range(153, 202)]
for fname in fnames:
    src = os.path.join('data/Humans', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['horse-{}.jpg'.format(i) for i in range(1,103)]
for fname in fnames:
    src = os.path.join('data/horses', fname)
    dst = os.path.join(train_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['horse-{}.jpg'.format(i) for i in range(103, 153)]
for fname in fnames:
    src = os.path.join('data/horses', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['horse-{}.jpg'.format(i) for i in range(153, 203)]
for fname in fnames:
    src = os.path.join('data/horses', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

# %%
path, dirs, files = next(os.walk("new_data/train"))
file_count = len(files)
print("train: ",file_count)
path, dirs, files = next(os.walk("new_data/validation"))
file_count = len(files)
print("validation: ",file_count)
path, dirs, files = next(os.walk("new_data/test"))
file_count = len(files)
print("test: ",file_count)
# Out:
# train:  408
# validation:  200
# test:  199

# %%
import cv2
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.subplot(141)
cat = cv2.imread('new_data/train/cat.1.jpg')
dim = cat.shape
plt.imshow(cat)
plt.axis("off")
plt.title(dim)

plt.subplot(142)
dog = cv2.imread('new_data/train/dog.6.jpg')
dim = dog.shape
plt.imshow(dog)
plt.axis("off")
plt.title(dim)

plt.subplot(143)
horse = cv2.imread('new_data/train/horse-7.jpg')
dim = horse.shape
plt.imshow(horse)
plt.axis("off")
plt.title(dim)

plt.subplot(144)
rider= cv2.imread('new_data/train/rider-98.jpg')
dim = rider.shape
plt.imshow(rider)
plt.axis("off")
plt.title(dim)
# Out:
# Text(0.5, 1.0, '(303, 166, 3)')

# %%
#All the images are of different dimensions, before building any model, we need to resize these images into same dimensions.

# %%
import numpy as np
from random import shuffle

IMG_SIZE = 224
LR = 1e-4

# %%
def label_img(img): 
  """This function labels each image as follows : 0 for cat, 1 for dog, 2 for horse, 3 for rider/human
  The argument to the function is a filename, which is a string. if string starts with cat then that image fie is labelled 0
  """
  #print(img)
  if img.startswith('cat'):        
    return 0

  elif img.startswith('dog'):
    return 1  

  elif img.startswith('horse'):
    return 2 

  elif img.startswith('rider'):
    return 3

# %%
def createDataSplitSet(datapath):
  """This function go through all files in given directory, reads each image file, resizes it to 224 * 224 , normalzes(minmax scaling) it
  and the appends image into list 'X' and its corresponding label into list 'y' """
  X=[]
  y=[]

  for img in os.listdir(datapath):
      label = label_img(img)       # calling function label_img to create label for the given image file
      # print(label)
      path = os.path.join(datapath, img)                          # for eg: fetch this file '/content/cats_and_dogs_small/train/cat.586.jpg'
      image = cv2.resize(cv2.imread(path), (IMG_SIZE, IMG_SIZE))  # resize it to 224 * 224
      image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
      # cv2.normalize(source,destination,minvalue,max value, normalization type,dtype)

      X.append(np.array(image))
      y.append(label)
  return np.array(X), np.array(y)

# %%
train_X, train_y = createDataSplitSet(train_dir)  # new_data/train
val_X, val_y = createDataSplitSet(validation_dir) # new_data/validation
test_X, test_y = createDataSplitSet(test_dir)     # new_data/test

# %%
test_y
# Out:
# array([1, 2, 0, 3, 0, 2, 0, 3, 2, 0, 0, 2, 0, 2, 0, 3, 2, 2, 3, 2, 2, 1,
#        0, 0, 0, 0, 2, 3, 2, 3, 1, 0, 3, 3, 3, 2, 1, 3, 2, 1, 1, 1, 0, 2,
#        0, 1, 0, 1, 0, 1, 1, 0, 1, 2, 0, 3, 2, 3, 3, 1, 0, 2, 1, 3, 2, 2,
#        1, 2, 0, 0, 1, 2, 1, 2, 1, 0, 0, 3, 2, 2, 0, 3, 0, 3, 1, 3, 1, 3,
#        0, 2, 1, 1, 1, 1, 1, 0, 1, 2, 3, 3, 1, 3, 2, 3, 1, 0, 1, 1, 0, 2,
#        1, 0, 2, 3, 3, 2, 3, 3, 3, 3, 1, 2, 2, 3, 1, 0, 2, 1, 2, 1, 0, 1,
#        2, 3, 1, 0, 3, 3, 3, 0, 1, 2, 2, 3, 3, 1, 0, 2, 3, 1, 0, 0, 3, 2,
#        0, 0, 1, 3, 0, 3, 1, 2, 2, 1, 3, 2, 2, 0, 3, 2, 2, 2, 0, 2, 2, 0,
#        1, 0, 3, 2, 3, 0, 3, 3, 0, 0, 0, 3, 1, 1, 1, 3, 1, 0, 2, 1, 3, 1,
#        0])

# %%
print(train_X.shape)
print(val_X.shape)
print(test_X.shape)
# Out:
# (408, 224, 224, 3)
# (200, 224, 224, 3)
# (199, 224, 224, 3)

# %% [markdown]
# # Feature Extraction

# %%
## Inception V3

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, Input, Flatten
from tensorflow.keras import Model

img_input = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# %%
model = InceptionV3(
    include_top=True,
    weights="imagenet",
    input_tensor=img_input,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
model.summary()
# Out:
# ...
# 96116736/96112376 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 111, 111, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
last_layer = model.get_layer('avg_pool').output
out = Dense(4, activation='softmax', name='output')(last_layer)  ## 4 classes
model = Model(img_input, out)

for layer in model.layers[:-1]:
	layer.trainable = False

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 111, 111, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 109, 109, 32) 9216        activation[0][0]
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
print(val_X.shape, val_y.shape)

from keras.utils import to_categorical

train_labels = to_categorical(train_y)
validation_labels = to_categorical(val_y)
test_labels = to_categorical(test_y)

print(train_labels.shape)
# Out:
# (200, 224, 224, 3) (200,)
# (408, 4)

# %%
history = model.fit(train_X, train_y,
                               batch_size=10,
                               epochs=10, 
                               validation_data=(val_X, val_y)
                               )
# Out:
# Epoch 1/10
# 41/41 [==============================] - 40s 96ms/step - loss: 0.9490 - acc: 0.6142 - val_loss: 0.2057 - val_acc: 0.9400
# Epoch 2/10
# 41/41 [==============================] - 2s 45ms/step - loss: 0.1541 - acc: 0.9437 - val_loss: 0.1461 - val_acc: 0.9500
# Epoch 3/10
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0765 - acc: 0.9673 - val_loss: 0.0903 - val_acc: 0.9650
# Epoch 4/10
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0404 - acc: 0.9999 - val_loss: 0.0834 - val_acc: 0.9700
# Epoch 5/10
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0367 - acc: 1.0000 - val_loss: 0.0783 - val_acc: 0.9650
# Epoch 6/10
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0194 - acc: 1.0000 - val_loss: 0.0755 - val_acc: 0.9750
# Epoch 7/10
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0140 - acc: 1.0000 - val_loss: 0.0724 - val_acc: 0.9650
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b*', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score

## Test Accuracy
predictions = model.predict(test_X)
#print(predictions)
y_classes = [np.argmax(element) for element in predictions]
#print(y_classes[:15])
#print(test_y[:15])

test_acc = accuracy_score(test_y, y_classes)

print("Test Accuracy:\t", test_acc,"\n")

from sklearn.metrics import precision_recall_fscore_support as score


precision, recall, fscore, support = score(test_y, y_classes)

print('precision: {}'.format(precision),"\n")
print('recall: {}'.format(recall),"\n")
print('fscore: {}'.format(fscore),"\n")
#print('support: {}'.format(support))
# Out:
# Test Accuracy:	 0.9698492462311558
#
# precision: [1.         0.94339623 0.96       0.97916667]
#
# recall: [0.96       1.         0.96       0.95918367]
#
# fscore: [0.97959184 0.97087379 0.96       0.96907216]

# %% [markdown]
# # FineTuning

# %%
model = InceptionV3(
    include_top=True,
    weights="imagenet",
    input_tensor=img_input,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax")

last_layer = model.get_layer('avg_pool').output
x= Flatten(name='flatten')(last_layer)
x = Dense(128, activation='relu', name='fc1')(x)
x = Dense(64, activation='relu', name='fc2')(x)
out = Dense(4, activation='softmax', name='output')(x)  ## 2 classes
model = Model(img_input, out)

for layer in model.layers[:-3]:
	layer.trainable = False

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_470 (Conv2D)             (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_470 (BatchN (None, 111, 111, 32) 96          conv2d_470[0][0]
# __________________________________________________________________________________________________
# activation_470 (Activation)     (None, 111, 111, 32) 0           batch_normalization_470[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

history = model.fit(train_X, train_y,
                               batch_size=10,
                               epochs=10, 
                               validation_data=(val_X, val_y)
                               )
# Out:
# Epoch 1/10
# 41/41 [==============================] - 2s 49ms/step - loss: 1.2549e-04 - acc: 1.0000 - val_loss: 0.0944 - val_acc: 0.9700
# Epoch 2/10
# 41/41 [==============================] - 2s 46ms/step - loss: 1.1634e-04 - acc: 1.0000 - val_loss: 0.0948 - val_acc: 0.9700
# Epoch 3/10
# 41/41 [==============================] - 2s 46ms/step - loss: 1.0813e-04 - acc: 1.0000 - val_loss: 0.0946 - val_acc: 0.9700
# Epoch 4/10
# 41/41 [==============================] - 2s 46ms/step - loss: 9.9438e-05 - acc: 1.0000 - val_loss: 0.0946 - val_acc: 0.9700
# Epoch 5/10
# 41/41 [==============================] - 2s 46ms/step - loss: 9.2060e-05 - acc: 1.0000 - val_loss: 0.0949 - val_acc: 0.9700
# Epoch 6/10
# 41/41 [==============================] - 2s 46ms/step - loss: 8.5506e-05 - acc: 1.0000 - val_loss: 0.0953 - val_acc: 0.9700
# Epoch 7/10
# 41/41 [==============================] - 2s 46ms/step - loss: 7.9752e-05 - acc: 1.0000 - val_loss: 0.0958 - val_acc: 0.9700
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b*', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score

## Test Accuracy
predictions = model.predict(test_X)

y_classes = [np.argmax(element) for element in predictions]

test_acc = accuracy_score(test_y, y_classes)

print("Test Accuracy:\t", test_acc,"\n")

from sklearn.metrics import precision_recall_fscore_support as score


precision, recall, fscore, support = score(test_y, y_classes)

print('precision: {}'.format(precision),"\n")
print('recall: {}'.format(recall),"\n")
print('fscore: {}'.format(fscore),"\n")
#print('support: {}'.format(support))
# Out:
# Test Accuracy:	 0.964824120603015
#
# precision: [1.         0.92592593 0.96       0.97916667]
#
# recall: [0.94       1.         0.96       0.95918367]
#
# fscore: [0.96907216 0.96153846 0.96       0.96907216]
